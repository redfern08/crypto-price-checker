# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import requests as rq
import pprint as pp
import json

# %% [markdown]
# Above, I imported all of the libraries I need to collect the necessary
# data.

# %%
pd.set_option('display.max_columns', 12)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# I then set options that will display the maximum number of columns
# and rows so I can search for specific data.

# %%
r = rq.get('http://api.coincap.io/v2/assets')
coin_data = r.json()
df = pd.DataFrame(coin_data['data'])
df
# Out:
#                          id rank symbol                   name  \
# 0                   bitcoin    1    BTC                Bitcoin
# 1                  ethereum    2    ETH               Ethereum
# 2                    tether    3   USDT                 Tether
# 3                  usd-coin    4   USDC               USD Coin
# 4              binance-coin    5    BNB                    BNB
# 5               binance-usd    6   BUSD            Binance USD
# 6                       xrp    7    XRP                    XRP
# 7                  dogecoin    8   DOGE               Dogecoin
# 8                   cardano    9    ADA                Cardano
# 9                   polygon   10  MATIC                Polygon
# 10     multi-collateral-dai   11    DAI   Multi Collateral DAI
# 11                 polkadot   12    DOT               Polkadot
# 12                 litecoin   13    LTC               Litecoin
# 13                   solana   14    SOL                 Solana
# ...

# %% [markdown]
# After options have been set, I created the data frame from the API.

# %%
df.set_index('symbol', inplace=True)

# %% [markdown]
# I went ahead and used the symbols as the row index instead of the standard int index.  This helps me to easier understance what coins I will be searching for and what each coins' symbol is.

# %%
df
# Out:
#                              id rank                   name  \
# symbol
# BTC                     bitcoin    1                Bitcoin
# ETH                    ethereum    2               Ethereum
# USDT                     tether    3                 Tether
# USDC                   usd-coin    4               USD Coin
# BNB                binance-coin    5                    BNB
# BUSD                binance-usd    6            Binance USD
# XRP                         xrp    7                    XRP
# DOGE                   dogecoin    8               Dogecoin
# ADA                     cardano    9                Cardano
# MATIC                   polygon   10                Polygon
# DAI        multi-collateral-dai   11   Multi Collateral DAI
# DOT                    polkadot   12               Polkadot
# LTC                    litecoin   13               Litecoin
# SOL                      solana   14                 Solana
# ...

# %%
df.iloc[0:5]
# Out:
#                   id rank      name                        supply  \
# symbol
# BTC          bitcoin    1   Bitcoin     19255537.0000000000000000
# ETH         ethereum    2  Ethereum    122373866.2178000000000000
# USDT          tether    3    Tether  66272490385.2489100000000000
# USDC        usd-coin    4  USD Coin  43799404551.5338400000000000
# BNB     binance-coin    5       BNB    166801148.0000000000000000
#
#                          maxSupply                   marketCapUsd  \
# symbol
# BTC      21000000.0000000000000000  326093935286.7335629714225099
# ETH                           None  154528399391.4707781654190307
# USDT                          None   66299928662.7598483442789737
# USDC                          None   43844097405.1357112245533863
# BNB     166801148.0000000000000000   43511826024.0338630889113972
#
#                       volumeUsd24Hr                priceUsd  \
# symbol
# BTC     3004961776.3760338932743663  16935.0735472468808827
# ...
